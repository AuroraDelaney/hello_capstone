# %%
import requests
import matplotlib.pyplot as plt
import json
import pandas as pd
import seaborn as sns
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
food = pd.read_csv('../data/Monthly_clean.csv')
food = food.reset_index(drop=True)
food.head(15)
# Out:
#       Year      Women    Infants   Children      Total   Food Costs  \
# 0   18-Oct  1,585,013  1,670,647  3,433,818  6,689,478  249,111,450
# 1   18-Nov  1,547,015  1,643,717  3,356,771  6,547,503  270,975,382
# 2   18-Dec  1,499,452  1,613,780  3,278,599  6,391,831  267,569,401
# 3   19-Jan  1,514,236  1,617,815  3,268,451  6,400,502  258,545,107
# 4   19-Feb  1,490,926  1,597,665  3,227,485  6,316,076  252,493,958
# 5   19-Mar  1,491,011  1,597,572  3,227,602  6,316,185  253,924,998
# 6   19-Apr  1,497,834  1,596,016  3,225,035  6,318,885  276,617,186
# 7   19-May  1,509,088  1,603,629  3,244,988  6,357,705  262,068,781
# 8   19-Jun  1,500,112  1,587,530  3,232,800  6,320,442  258,695,834
# 9   19-Jul  1,515,497  1,597,911  3,251,625  6,365,033  260,020,850
# 10  19-Aug  1,520,020  1,599,609  3,268,005  6,387,634  244,231,452
# 11  19-Sep  1,508,381  1,590,550  3,247,086  6,346,017  285,088,702
# 12  19-Oct  1,510,437  1,594,711  3,231,757  6,336,905  234,395,285
# 13  19-Nov  1,470,041  1,562,252  3,161,002  6,193,295  256,527,101
# 14  19-Dec  1,437,854  1,545,072  3,097,555  6,080,481  264,363,281
#
#      NSA* Costs  AVG Food Cost
# 0   621,616,739          37.24
# 1    92,071,643          41.39
# 2   157,454,966          41.86
# 3   119,006,927          40.39
# 4   109,627,239          39.98
# 5    95,205,344          40.20
# 6   126,331,091          43.78
# 7   103,736,599          41.22
# 8   111,776,129          40.93
# 9   118,667,268          40.85
# 10  116,873,543          38.24
# 11  214,060,053          44.92
# 12  569,310,351          36.99
# 13  102,590,256          41.42
# 14  198,491,523          43.48

# %% [markdown]
# food.info()

# %% [markdown]
# food.columns

# %% [markdown]
# food_subset = food[['Fiscal', 'PROGRAM PARTICIPATION', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Food', 'NSA*', 'Average']]
# food_subset.head(20)

# %%
inflation = pd.read_csv('../data/inflation_data.csv')
inflation = inflation.reset_index(drop=True)
inflation.head()
# Out:
#    year  amount  inflation rate
# 0  2012    1.00            0.02
# 1  2013    1.01            0.01
# 2  2014    1.03            0.02
# 3  2015    1.03            0.00
# 4  2016    1.05            0.01

# %%
eat = pd.read_csv('../data/Yearly_clean.csv')
eat = eat.reset_index(drop=True)
eat.head(5)
# Out:
#       YEAR      Women    Infants   Children      Total     Food Costs  \
# 0  FY 2021  1,379,161  1,464,732  3,400,098  6,243,990  2,647,989,412
# 1  FY 2020  1,446,146  1,551,034  3,250,234  6,247,414  2,884,448,549
# 2  FY 2019  1,514,882  1,609,703  3,271,855  6,396,441  3,139,343,101
# 3  FY 2018  1,633,864  1,712,401  3,523,863  6,870,128  3,374,688,123
#
#       NSA* Costs  AVG Food Cost
# 0  2,017,533,294          35.34
# 1  1,984,059,680          38.48
# 2  1,986,427,541          40.90
# 3  1,976,341,659          40.93

# %% [markdown]
# eat.transpose()

# %% [markdown]
# eat.info

# %%
avgfc = pd.read_csv('../data/avg monthly benefit per person state_clean.csv')
avgfc = avgfc.reset_index(drop=True)
avgfc.head(10)
# Out:
#   State / Indian Tribe           FY 2012  FY 2013  FY 2014  FY 2015  FY 2016
# 0                       Alabama    49.87    46.59    45.19    48.34    45.52
# 1                        Alaska    53.74    50.48    54.64    52.61    52.94
# 2                American Samoa    70.18    69.41    70.52    72.94    74.51
# 3                       Arizona    42.16    42.88    44.09    45.55    44.93
# 4                      Arkansas    45.79    46.51    43.90    43.81    43.09
# 5                    California    49.35    46.05    47.21    47.80    46.09
# 6                      Colorado    40.56    40.61    40.99    41.36    41.03
# 7                   Connecticut    52.19    42.25    46.22    48.04    43.65
# 8                      Delaware    40.85    37.85    40.07    40.55    40.07
# 9          District of Columbia    44.02    45.18    42.66    44.01    42.83

# %% [markdown]
# avgfc.info()

# %%
foodcost = pd.read_csv('../data/State_clean.csv')
foodcost = foodcost.reset_index(drop=True)
foodcost.head()
# Out:
#   State               16-Feb Jan-17 Prelim Feb-17 Initial % Change vs Jan-17  \
# 0           Alabama  128,220       126,063        122,917             -2.50%
# 1            Alaska   18,913        18,446         18,070             -2.00%
# 2    American Samoa    6,042         5,716          5,696             -0.30%
# 3           Arizona  161,429       150,688        146,085             -3.10%
# 4          Arkansas   79,899        76,349         75,739             -0.80%
#
#   % Change vs Feb-16
# 0             -4.10%
# 1             -4.50%
# 2             -5.70%
# 3             -9.50%
# 4             -5.20%

# %% [markdown]
# foodcost.info()

# %% [markdown]
# foodcost.head(15)

# %%
Totalfc = pd.concat([foodcost, avgfc])
Totalfc.head(20)
# Out:
#        State                 16-Feb Jan-17 Prelim Feb-17 Initial  \
# 0                Alabama    128,220       126,063        122,917
# 1                 Alaska     18,913        18,446         18,070
# 2         American Samoa      6,042         5,716          5,696
# 3                Arizona    161,429       150,688        146,085
# 4               Arkansas     79,899        76,349         75,739
# 5             California  1,174,784     1,113,961      1,074,629
# 6               Colorado     86,522        83,691         83,354
# 7            Connecticut     48,351        47,993         46,865
# 8               Delaware     18,210        16,751         16,524
# 9   District of Columbia     14,081        14,029         13,586
# 10               Florida    477,177       472,252        436,692
# 11               Georgia    252,786       242,428        238,233
# 12                  Guam      7,151         6,660          6,639
# 13                Hawaii     30,343        28,249         26,858
# 14                 Idaho     39,132        36,948         36,675
# 15              Illinois    224,064       214,629        210,192
# 16               Indiana    147,464       144,272        141,586
# 17                  Iowa     60,665        62,367         62,104
# 18                Kansas     59,238        55,541         53,618
# 19              Kentucky    110,861       108,079        107,839
#
#    % Change vs Jan-17 % Change vs Feb-16 State / Indian Tribe           \
# 0              -2.50%             -4.10%                           NaN
# 1              -2.00%             -4.50%                           NaN
# 2              -0.30%             -5.70%                           NaN
# 3              -3.10%             -9.50%                           NaN
# 4              -0.80%             -5.20%                           NaN
# 5              -3.50%             -8.50%                           NaN
# 6              -0.40%             -3.70%                           NaN
# 7              -2.40%             -3.10%                           NaN
# 8              -1.40%             -9.30%                           NaN
# 9              -3.20%             -3.50%                           NaN
# 10             -7.50%             -8.50%                           NaN
# 11             -1.70%             -5.80%                           NaN
# 12             -0.30%             -7.20%                           NaN
# 13             -4.90%            -11.50%                           NaN
# 14             -0.70%             -6.30%                           NaN
# 15             -2.10%             -6.20%                           NaN
# 16             -1.90%             -4.00%                           NaN
# 17             -0.40%              2.40%                           NaN
# 18             -3.50%             -9.50%                           NaN
# 19             -0.20%             -2.70%                           NaN
#
#     FY 2012  FY 2013  FY 2014  FY 2015  FY 2016
# 0       NaN      NaN      NaN      NaN      NaN
# 1       NaN      NaN      NaN      NaN      NaN
# 2       NaN      NaN      NaN      NaN      NaN
# 3       NaN      NaN      NaN      NaN      NaN
# 4       NaN      NaN      NaN      NaN      NaN
# 5       NaN      NaN      NaN      NaN      NaN
# 6       NaN      NaN      NaN      NaN      NaN
# 7       NaN      NaN      NaN      NaN      NaN
# 8       NaN      NaN      NaN      NaN      NaN
# 9       NaN      NaN      NaN      NaN      NaN
# 10      NaN      NaN      NaN      NaN      NaN
# 11      NaN      NaN      NaN      NaN      NaN
# 12      NaN      NaN      NaN      NaN      NaN
# 13      NaN      NaN      NaN      NaN      NaN
# 14      NaN      NaN      NaN      NaN      NaN
# 15      NaN      NaN      NaN      NaN      NaN
# 16      NaN      NaN      NaN      NaN      NaN
# 17      NaN      NaN      NaN      NaN      NaN
# 18      NaN      NaN      NaN      NaN      NaN
# 19      NaN      NaN      NaN      NaN      NaN

# %%
Totalfc.isna().sum()
# Out:
# State                            56
# 16-Feb                           56
# Jan-17 Prelim                    56
# Feb-17 Initial                   56
# % Change vs Jan-17               56
# % Change vs Feb-16               56
# State / Indian Tribe             56
# FY 2012                          56
# FY 2013                          56
# FY 2014                          56
# FY 2015                          56
# FY 2016                          56
# dtype: int64

# %%
Totalfc.describe()
# Out:
#          FY 2012    FY 2013    FY 2014    FY 2015    FY 2016
# count  56.000000  56.000000  56.000000  56.000000  56.000000
# mean   46.579286  45.576071  45.733393  45.696786  45.013036
# std    11.711199  11.892573  11.090192  11.871664  12.037797
# min    29.300000  26.460000  29.270000  28.890000  29.920000
# 25%    39.870000  39.027500  39.137500  38.415000  37.957500
# 50%    43.685000  43.165000  43.795000  43.730000  42.265000
# 75%    49.480000  47.642500  47.427500  48.115000  46.562500
# max    88.570000  88.980000  83.070000  86.380000  88.080000

# %% [markdown]
# Totalfc.info

# %%
FoodInflation = pd.concat([eat, inflation])
FoodInflation.head(20)
# Out:
#        YEAR      Women    Infants   Children      Total     Food Costs  \
# 0   FY 2021  1,379,161  1,464,732  3,400,098  6,243,990  2,647,989,412
# 1   FY 2020  1,446,146  1,551,034  3,250,234  6,247,414  2,884,448,549
# 2   FY 2019  1,514,882  1,609,703  3,271,855  6,396,441  3,139,343,101
# 3   FY 2018  1,633,864  1,712,401  3,523,863  6,870,128  3,374,688,123
# 0       NaN        NaN        NaN        NaN        NaN            NaN
# 1       NaN        NaN        NaN        NaN        NaN            NaN
# 2       NaN        NaN        NaN        NaN        NaN            NaN
# 3       NaN        NaN        NaN        NaN        NaN            NaN
# 4       NaN        NaN        NaN        NaN        NaN            NaN
# 5       NaN        NaN        NaN        NaN        NaN            NaN
# 6       NaN        NaN        NaN        NaN        NaN            NaN
# 7       NaN        NaN        NaN        NaN        NaN            NaN
# 8       NaN        NaN        NaN        NaN        NaN            NaN
# 9       NaN        NaN        NaN        NaN        NaN            NaN
# 10      NaN        NaN        NaN        NaN        NaN            NaN
#
#        NSA* Costs  AVG Food Cost    year  amount  inflation rate
# 0   2,017,533,294          35.34     NaN     NaN             NaN
# 1   1,984,059,680          38.48     NaN     NaN             NaN
# 2   1,986,427,541          40.90     NaN     NaN             NaN
# 3   1,976,341,659          40.93     NaN     NaN             NaN
# 0             NaN            NaN  2012.0    1.00            0.02
# 1             NaN            NaN  2013.0    1.01            0.01
# 2             NaN            NaN  2014.0    1.03            0.02
# 3             NaN            NaN  2015.0    1.03            0.00
# 4             NaN            NaN  2016.0    1.05            0.01
# 5             NaN            NaN  2017.0    1.07            0.02
# 6             NaN            NaN  2018.0    1.09            0.02
# 7             NaN            NaN  2019.0    1.11            0.02
# 8             NaN            NaN  2020.0    1.13            0.01
# 9             NaN            NaN  2021.0    1.18            0.05
# 10            NaN            NaN  2022.0    1.26            0.07

# %%
FoodInflation.index = pd.DatetimeIndex(FoodInflation.index)
FoodInflation = FoodInflation.reset_index(drop=True)

# %%
FoodInflation.hist(bins=10, figsize=[20, 10])
# Out:
# array([[<AxesSubplot:title={'center':'AVG Food Cost'}>,
#         <AxesSubplot:title={'center':'year'}>],
#        [<AxesSubplot:title={'center':'amount'}>,
#         <AxesSubplot:title={'center':'inflation rate'}>]], dtype=object)

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)

plt.plot(x, y, 'o', color='gray',
         markersize=15, linewidth=4,
         markerfacecolor='white',
         markeredgecolor='gray',
         markeredgewidth=2)
plt.ylim(-1.2, 1.2)
plt.xlabel(FoodInflation.amount[0])
plt.ylabel(FoodInflation.year[1]);

#FoodInflation[['amount', 'year', 'inflation rate']].plot(style=".")

# %%
FoodInflation.isna().sum()
# Out:
# YEAR              11
# Women             11
# Infants           11
# Children          11
# Total             11
# Food Costs        11
# NSA* Costs        11
# AVG Food Cost     11
# year               4
# amount             4
# inflation rate     4
# dtype: int64

# %%
FoodInflation.describe()
# Out:
#        AVG Food Cost         year     amount  inflation rate
# count       4.000000    11.000000  11.000000       11.000000
# mean       38.912500  2017.000000   1.087273        0.022727
# std         2.643878     3.316625   0.079132        0.020045
# min        35.340000  2012.000000   1.000000        0.000000
# 25%        37.695000  2014.500000   1.030000        0.010000
# 50%        39.690000  2017.000000   1.070000        0.020000
# 75%        40.907500  2019.500000   1.120000        0.020000
# max        40.930000  2022.000000   1.260000        0.070000

# %%
FoodInflation.columns
# Out:
# Index(['YEAR', 'Women', 'Infants', 'Children', 'Total', 'Food Costs',
#        'NSA* Costs', 'AVG Food Cost', 'year', 'amount', 'inflation rate'],
#       dtype='object')

# %%
FoodInflation.rename(columns={'0:State/Indian Tribe', '1:'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15472/1963705302.py in <module>
# ----> 1 FoodInflation.rename(columns={'0:State/Indian Tribe', '1:'})
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     322         @wraps(func)
#     323         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 324             return func(*args, **kwargs)
#     325
#     326         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    5037         4  3  6
#    5038         """
# -> 5039         return super().rename(
#    5040             mapper=mapper,
#    5041             index=index,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    1154                     raise KeyError(f"{missing_labels} not found in axis")
#    1155
# -> 1156             new_index = ax._transform_index(f, level)
#    1157             result._set_axis_nocheck(new_index, axis=axis_no, inplace=True)
#    1158             result._clear_item_cache()
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _transform_index(self, func, level)
#    5544             return type(self).from_tuples(items, names=self.names)
#    5545         else:
# -> 5546             items = [func(x) for x in self]
#    5547             return Index(items, name=self.name, tupleize_cols=False)
#    5548
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in <listcomp>(.0)
#    5544             return type(self).from_tuples(items, names=self.names)
#    5545         else:
# -> 5546             items = [func(x) for x in self]
#    5547             return Index(items, name=self.name, tupleize_cols=False)
#    5548
#
# TypeError: 'set' object is not callable

# %% [markdown]
# FoodInflation_subset = FoodInflation(['Unnamed:0', 'Percent Change', 'year', 'amount', 'inflation rate'])
# FoodInflation_subset

# %%
FoodInflation.groupby(['inflation rate', 'year'])['amount'].count().sort_values(ascending=False).unstack()

# %%
import requests
import matplotlib.pyplot as plt
import json
import pandas as pd
import seaborn as sns
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
food = pd.read_csv('../data/37WIC_Monthly-5.csv')
food = food.reset_index(drop=True)
food.head()
# Out:
#   SPECIAL SUPPLEMENTAL NUTRITION PROGRAM FOR WOMEN, INFANTS AND CHILDREN (WIC)  \
# 0                         ( Data as of May 13, 2022)
# 1                                             Fiscal
# 2                                               Year
# 3                                     ANNUAL SUMMARY
# 4                                            FY 2021
#
#               Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4     Unnamed: 5  \
# 0                    NaN        NaN        NaN        NaN            NaN
# 1  PROGRAM PARTICIPATION        NaN        NaN        NaN           Food
# 2                  Women    Infants   Children      Total          Costs
# 3                    NaN        NaN        NaN        NaN            NaN
# 4              1,379,161  1,464,732  3,400,098  6,243,990  2,647,989,412
#
#       Unnamed: 6 Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 22  \
# 0            NaN        NaN         NaN         NaN  ...          NaN
# 1           NSA*    Average         NaN         NaN  ...          NaN
# 2          Costs  Food Cost         NaN         NaN  ...          NaN
# 3            NaN        NaN         NaN         NaN  ...          NaN
# 4  2,017,533,294      35.34         NaN         NaN  ...          NaN
#
#    Unnamed: 23  Unnamed: 24  Unnamed: 25  Unnamed: 26  Unnamed: 27  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 28  Unnamed: 29  Unnamed: 30  Unnamed: 31
# 0          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN
#
# [5 rows x 32 columns]

# %%
eat = pd.read_csv('../data/37WIC_Monthly-5-2.csv')
eat = eat.reset_index(drop=True)
eat.head()
# Out:
#   WIC PROGRAM:  TOTAL PARTICIPATION Unnamed: 1   Unnamed: 2 Unnamed: 3  \
# 0         (Data as of May 05, 2017)        NaN          NaN        NaN
# 1                               NaN        NaN          NaN        NaN
# 2               State /               February      January   February
# 3               Territory                 2016         2017       2017
# 4                               NaN        NaN  Preliminary    Initial
#
#           Unnamed: 4 Unnamed: 5
# 0                NaN        NaN
# 1     Percent Change        NaN
# 2  February 2017 vs:        NaN
# 3            Jan. 17    Feb. 16
# 4                NaN        NaN

# %%
avgfc = pd.read_csv('../data/37WIC-avgfoodcost.csv')
avgfc = avgfc.reset_index(drop=True)
avgfc.head()
# Out:
#   WIC PROGRAM:  AVERAGE MONTHLY BENEFIT PER PERSON Unnamed: 1 Unnamed: 2  \
# 0                        (Data as of May 05, 2017)        NaN        NaN
# 1                    State / Indian Tribe             FY 2012    FY 2013
# 2                                              NaN        NaN        NaN
# 3                                          Alabama      49.87      46.59
# 4                                           Alaska      53.74      50.48
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0        NaN        NaN        NaN
# 1    FY 2014    FY 2015    FY 2016
# 2        NaN        NaN        NaN
# 3      45.19      48.34      45.52
# 4      54.64      52.61      52.94

# %%
foodcost = pd.read_csv('../data/37WIC-foodcost.csv')
foodcost = foodcost.reset_index(drop=True)
foodcost.head()
# Out:
#          WIC PROGRAM:  FOOD COST  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0      (Data as of May 05, 2017)         NaN         NaN         NaN
# 1  State / Indian Tribe              FY 2012     FY 2013     FY 2014
# 2                            NaN         NaN         NaN         NaN
# 3                        Alabama  84,923,273  77,704,135  71,057,962
# 4                         Alaska  16,102,872  13,965,769  12,855,268
#
#    Unnamed: 4  Unnamed: 5
# 0         NaN         NaN
# 1     FY 2015     FY 2016
# 2         NaN         NaN
# 3  76,644,919  70,551,498
# 4  12,424,923  12,146,098
